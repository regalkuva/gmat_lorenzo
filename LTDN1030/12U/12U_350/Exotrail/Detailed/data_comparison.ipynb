# %%
import pandas as pd
import matplotlib.pyplot as plt
import statistics


# path_12u_highdrag = 'C:/Users/egeme/Desktop/Kuva/GMAT_OrbitalSims/LTDN1030/12U/12U_350/Exotrail/Detailed/12U_ExotrailM+_PerpendicularLifetime.txt'
# path_12u_highdrag_lowsfu = 'C:/Users/egeme/Desktop/Kuva/GMAT_OrbitalSims/LTDN1030/12U/12U_350/Exotrail/Detailed/12U_ExotrailM+_PerpendicularLifetime_LowSFU.txt'
# path_12u_highdrag_midsfu = 'C:/Users/egeme/Desktop/Kuva/GMAT_OrbitalSims/LTDN1030/12U/12U_350/Exotrail/Detailed/12U_ExotrailM+_PerpendicularLifetime_MidSFU.txt'

# path_12u_lowdrag = 'C:/Users/egeme/Desktop/Kuva/GMAT_OrbitalSims/LTDN1030/12U/12U_350/Exotrail/Detailed/12U_ExotrailM+_Lifetime.txt'
# path_12u_lowdrag_midsfu = 'C:/Users/egeme/Desktop/Kuva/GMAT_OrbitalSims/LTDN1030/12U/12U_350/Exotrail/Detailed/12U_ExotrailM+_Lifetime_MidSFU.txt'
# path_12u_lowdrag_lowsfu = 'C:/Users/egeme/Desktop/Kuva/GMAT_OrbitalSims/LTDN1030/12U/12U_350/Exotrail/Detailed/12U_ExotrailM+_Lifetime_LowSFU.txt'

path_16u_highdrag = 'C:/Users/egeme/Desktop/Kuva/GMAT_OrbitalSims/LTDN1030/12U/12U_350/Exotrail/Detailed/16U_Exotrail_LifetimeL_Perpendicular.txt'
path_16u_highdrag_midsfu = 'C:/Users/egeme/Desktop/Kuva/GMAT_OrbitalSims/LTDN1030/12U/12U_350/Exotrail/Detailed/16U_Exotrail_LifetimeL_Perpendicular_MidSFU.txt'
path_16u_highdrag_lowsfu = 'C:/Users/egeme/Desktop/Kuva/GMAT_OrbitalSims/LTDN1030/12U/12U_350/Exotrail/Detailed/16U_Exotrail_LifetimeL_Perpendicular_LowSFU.txt'

path_16u_lowdrag = 'C:/Users/egeme/Desktop/Kuva/GMAT_OrbitalSims/LTDN1030/12U/12U_350/Exotrail/Detailed/16U_Exotrail_LifetimeL.txt'
path_16u_lowdrag_lowsfu = 'C:/Users/egeme/Desktop/Kuva/GMAT_OrbitalSims/LTDN1030/12U/12U_350/Exotrail/Detailed/16U_Exotrail_LifetimeL_LowSFU.txt'
path_16u_lowdrag_midsfu = 'C:/Users/egeme/Desktop/Kuva/GMAT_OrbitalSims/LTDN1030/12U/12U_350/Exotrail/Detailed/16U_Exotrail_LifetimeL_MidSFU.txt'


# dataset_12u_highdrag = pd.read_fwf(path_12u_highdrag)
# dataset_12u_highdrag_lowsfu = pd.read_fwf(path_12u_highdrag_lowsfu)
# dataset_12u_highdrag_midsfu = pd.read_fwf(path_12u_highdrag_midsfu)

# dataset_12u_lowdrag =  pd.read_fwf(path_12u_lowdrag)
# dataset_12u_lowdrag_midsfu =  pd.read_fwf(path_12u_lowdrag_midsfu)
# dataset_12u_lowdrag_lowsfu =  pd.read_fwf(path_12u_lowdrag_lowsfu)

dataset_16u_highdrag = pd.read_fwf(path_16u_highdrag)
dataset_16u_highdrag_lowsfu = pd.read_fwf(path_16u_highdrag_lowsfu)
dataset_16u_highdrag_midsfu = pd.read_fwf(path_16u_highdrag_midsfu)

dataset_16u_lowdrag = pd.read_fwf(path_16u_lowdrag)
dataset_16u_lowdrag_lowsfu = pd.read_fwf(path_16u_lowdrag_lowsfu)
dataset_16u_lowdrag_midsfu = pd.read_fwf(path_16u_lowdrag_midsfu)

# %%
elapsed_days16low = dataset_16u_lowdrag['SC.ElapsedDays'].values.tolist()
elapsed_days16low_lowsfu = dataset_16u_lowdrag_lowsfu['SC.ElapsedDays'].values.tolist()
elapsed_days16low_midsfu = dataset_16u_lowdrag_midsfu['SC.ElapsedDays'].values.tolist()


# elapsed_days12low = dataset_12u_lowdrag['SC.ElapsedDays'].values.tolist()
# elapsed_days12high = dataset_12u_highdrag['SC.ElapsedDays'].values.tolist()

# elapsed_days12high_lowsfu = dataset_12u_highdrag_lowsfu['SC.ElapsedDays'].values.tolist()
# elapsed_days12high_midsfu = dataset_12u_highdrag_midsfu['SC.ElapsedDays'].values.tolist()

# elapsed_days12low_lowsfu = dataset_12u_lowdrag_lowsfu['SC.ElapsedDays'].values.tolist()
# elapsed_days12low_midsfu = dataset_12u_lowdrag_midsfu['SC.ElapsedDays'].values.tolist()

elapsed_days16high = dataset_16u_highdrag['SC.ElapsedDays'].values.tolist()
elapsed_days16high_midsfu = dataset_16u_highdrag_midsfu['SC.ElapsedDays'].values.tolist()
elapsed_days16high_lowsfu = dataset_16u_highdrag_lowsfu['SC.ElapsedDays'].values.tolist()

sma_16lowdrag = dataset_16u_lowdrag['SC.Earth.SMA'].values.tolist()
sma_16lowdrag_lowsfu = dataset_16u_lowdrag_lowsfu['SC.Earth.SMA'].values.tolist()
sma_16lowdrag_midsfu = dataset_16u_lowdrag_midsfu['SC.Earth.SMA'].values.tolist()

sma_16highdrag = dataset_16u_highdrag['SC.Earth.SMA'].values.tolist()
sma_16highdrag_lowsfu = dataset_16u_highdrag_lowsfu['SC.Earth.SMA'].values.tolist()
sma_16highdrag_midsfu = dataset_16u_highdrag_midsfu['SC.Earth.SMA'].values.tolist()

fuel_qty_16lowdrag_lowsfu = dataset_16u_lowdrag_lowsfu['SC.ElectricTank1.FuelMass'].values.tolist()
fuel_qty_16lowdrag_midsfu = dataset_16u_lowdrag_midsfu['SC.ElectricTank1.FuelMass'].values.tolist()
fuel_qty_16lowdrag_highsfu = dataset_16u_lowdrag['SC.ElectricTank1.FuelMass'].values.tolist()

fuel_qty_16highdrag_lowsfu = dataset_16u_highdrag_lowsfu['SC.ElectricTank1.FuelMass'].values.tolist()
fuel_qty_16highdrag_midsfu = dataset_16u_highdrag_midsfu['SC.ElectricTank1.FuelMass'].values.tolist()
fuel_qty_16highdrag_highsfu = dataset_16u_highdrag['SC.ElectricTank1.FuelMass'].values.tolist()

changelist_16u_lowdrag_lowsfu = [i for i in range(1,len(fuel_qty_16lowdrag_lowsfu)) if fuel_qty_16lowdrag_lowsfu[i]!=fuel_qty_16lowdrag_lowsfu[i-1] ]
changelist_16u_lowdrag_midsfu = [i for i in range(1,len(fuel_qty_16lowdrag_midsfu)) if fuel_qty_16lowdrag_midsfu[i]!=fuel_qty_16lowdrag_midsfu[i-1] ]
changelist_16u_lowdrag_highsfu = [i for i in range(1,len(fuel_qty_16lowdrag_highsfu)) if fuel_qty_16lowdrag_highsfu[i]!=fuel_qty_16lowdrag_highsfu[i-1] ]

changelist_16u_highdrag_lowsfu = [i for i in range(1,len(fuel_qty_16highdrag_lowsfu)) if fuel_qty_16highdrag_lowsfu[i]!=fuel_qty_16highdrag_lowsfu[i-1] ]
changelist_16u_highdrag_midsfu = [i for i in range(1,len(fuel_qty_16highdrag_midsfu)) if fuel_qty_16highdrag_midsfu[i]!=fuel_qty_16highdrag_midsfu[i-1] ]
changelist_16u_highdrag_highsfu = [i for i in range(1,len(fuel_qty_16highdrag_highsfu)) if fuel_qty_16highdrag_highsfu[i]!=fuel_qty_16highdrag_highsfu[i-1] ]

# sma_12highdrag = dataset_12u_highdrag['SC.Earth.SMA'].values.tolist()
# sma_12highdrag_lowsfu = dataset_12u_highdrag_lowsfu['SC.Earth.SMA'].values.tolist()
# sma_12highdrag_midsfu = dataset_12u_highdrag_midsfu['SC.Earth.SMA'].values.tolist()

# sma_12lowdrag = dataset_12u_lowdrag['SC.Earth.SMA'].values.tolist()
# sma_12lowdrag_lowsfu = dataset_12u_lowdrag_lowsfu['SC.Earth.SMA'].values.tolist()
# sma_12lowdrag_midsfu = dataset_12u_lowdrag_midsfu['SC.Earth.SMA'].values.tolist()

# %%
plt.figure(figsize=(18,10))

# plt.plot(elapsed_days16high,sma_16highdrag)
# plt.plot(elapsed_days12low,sma_12lowdrag)

# plt.plot(elapsed_days12high_lowsfu, sma_12highdrag_lowsfu, label='12U High Drag, 130 SFU')
# plt.plot(elapsed_days12high_midsfu, sma_12highdrag_midsfu, label='12U High Drag, 160 SFU')
# plt.plot(elapsed_days12high, sma_12highdrag, label='12U High Drag, 190 SFU')

# plt.plot(elapsed_days16high_lowsfu, sma_16highdrag_lowsfu, label='16U High Drag, 130 SFU')
# plt.plot(elapsed_days16high_midsfu, sma_16highdrag_midsfu, label='16U High Drag, 160 SFU')
# plt.plot(elapsed_days16high, sma_16highdrag, label='16U High Drag, 190 SFU')

# plt.plot(elapsed_days12low_lowsfu, sma_12lowdrag_lowsfu, label='12U Low Drag, 130 SFU')
# plt.plot(elapsed_days12low_midsfu, sma_12lowdrag_midsfu, label='12U Low Drag, 160 SFU')
# plt.plot(elapsed_days12low, sma_12lowdrag, label='12U Low Drag, 190 SFU')

plt.plot(elapsed_days16low_lowsfu, sma_16lowdrag_lowsfu, label='16U Low Drag,130 SFU')
plt.plot(elapsed_days16low_midsfu, sma_16lowdrag_midsfu, label='16U Low Drag,160 SFU')
plt.plot(elapsed_days16low, sma_16lowdrag, label='16U Low Drag,190 SFU')
plt.legend()

plt.axhline(6718.14, color='red',linestyle='--')
plt.text(2800,6725.14,'350km Line', color='red')

plt.text(elapsed_days16low_lowsfu[changelist_16u_lowdrag_lowsfu[-1]],6735.14,f'{elapsed_days16low_lowsfu[changelist_16u_lowdrag_lowsfu[-1]] - elapsed_days16low_lowsfu[changelist_16u_lowdrag_lowsfu[0]]:.2f} days', color='Blue')
plt.text(elapsed_days16low_midsfu[changelist_16u_lowdrag_midsfu[-1]],6735.14,f'{elapsed_days16low_midsfu[changelist_16u_lowdrag_midsfu[-1]] - elapsed_days16low_midsfu[changelist_16u_lowdrag_midsfu[0]]:.2f} days', color='Orange')
plt.text(elapsed_days16low[changelist_16u_lowdrag_highsfu[-1]],6735.14,f'{elapsed_days16low[changelist_16u_lowdrag_highsfu[-1]] - elapsed_days16low[changelist_16u_lowdrag_highsfu[0]]:.2f} days', color='Green')

plt.axvline(elapsed_days16low_lowsfu[changelist_16u_lowdrag_lowsfu[-1]],0,0.81,color='blue',linestyle='-.')
plt.axvline(elapsed_days16low_midsfu[changelist_16u_lowdrag_midsfu[-1]],0,0.81,color='orange',linestyle='-.')
plt.axvline(elapsed_days16low[changelist_16u_lowdrag_highsfu[-1]],0,0.81,color='green',linestyle='-.')
plt.ylabel('SMA (km)')
plt.xlabel('Elapsed Days')


plt.show()

# %%
plt.figure(figsize=(18,10))

# plt.plot(elapsed_days16high,sma_16highdrag)
# plt.plot(elapsed_days12low,sma_12lowdrag)

# plt.plot(elapsed_days12high_lowsfu, sma_12highdrag_lowsfu, label='12U High Drag, 130 SFU')
# plt.plot(elapsed_days12high_midsfu, sma_12highdrag_midsfu, label='12U High Drag, 160 SFU')
# plt.plot(elapsed_days12high, sma_12highdrag, label='12U High Drag, 190 SFU')

plt.plot(elapsed_days16high_lowsfu, sma_16highdrag_lowsfu, label='16U High Drag, 130 SFU')
plt.plot(elapsed_days16high_midsfu, sma_16highdrag_midsfu, label='16U High Drag, 160 SFU')
plt.plot(elapsed_days16high, sma_16highdrag, label='16U High Drag, 190 SFU')

# plt.plot(elapsed_days12low_lowsfu, sma_12lowdrag_lowsfu, label='12U Low Drag, 130 SFU')
# plt.plot(elapsed_days12low_midsfu, sma_12lowdrag_midsfu, label='12U Low Drag, 160 SFU')
# plt.plot(elapsed_days12low, sma_12lowdrag, label='12U Low Drag, 190 SFU')

# plt.plot(elapsed_days16low_lowsfu, sma_16lowdrag_lowsfu, label='16U Low Drag,130 SFU')
# plt.plot(elapsed_days16low_midsfu, sma_16lowdrag_midsfu, label='16U Low Drag,160 SFU')
# plt.plot(elapsed_days16low, sma_16lowdrag, label='16U Low Drag,190 SFU')
plt.legend()

plt.axhline(6718.14, color='red',linestyle='--')
plt.text(1100,6725.14,'350km Line', color='red')

plt.text(elapsed_days16high_lowsfu[changelist_16u_highdrag_lowsfu[-1]],6735.14,f'{elapsed_days16high_lowsfu[changelist_16u_highdrag_lowsfu[-1]] - elapsed_days16high_lowsfu[changelist_16u_highdrag_lowsfu[0]]:.2f} days', color='Blue')
plt.text(elapsed_days16high_midsfu[changelist_16u_highdrag_midsfu[-1]],6735.14,f'{elapsed_days16high_midsfu[changelist_16u_highdrag_midsfu[-1]] - elapsed_days16high_midsfu[changelist_16u_highdrag_midsfu[0]]:.2f} days', color='Orange')
plt.text(elapsed_days16high[changelist_16u_highdrag_highsfu[-1]],6735.14,f'{elapsed_days16high[changelist_16u_highdrag_highsfu[-1]] - elapsed_days16high[changelist_16u_highdrag_highsfu[0]]:.2f} days', color='Green')

plt.axvline(elapsed_days16high_lowsfu[changelist_16u_highdrag_lowsfu[-1]],0,0.81,color='blue',linestyle='-.')
plt.axvline(elapsed_days16high_midsfu[changelist_16u_highdrag_midsfu[-1]],0,0.81,color='orange',linestyle='-.')
plt.axvline(elapsed_days16high[changelist_16u_highdrag_highsfu[-1]],0,0.81,color='green',linestyle='-.')
plt.ylabel('SMA (km)')
plt.xlabel('Elapsed Days')


plt.show()
